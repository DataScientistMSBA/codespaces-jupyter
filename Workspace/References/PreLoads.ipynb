# %% [markdown]
# **PreLoads: Installs**

# %%
# def RunPIP():
#   from IPython.display import clear_output; global clear_output; clear_output(wait=True)
#   !pip install "s3fs<=0.4" paramiko pysftp phonenumbers pgpy
#   clear_output(wait=True)
#   !pip install presto-python-client
#   clear_output(wait=True)
#   !pip install sodapy
#   clear_output(wait=True)
#   !pip install beautifulsoup4
#   clear_output(wait=True)
#   !pip install lxml
#   clear_output(wait=True)
#   !pip install selenium
#   clear_output(wait=True)
#   !pip install xlrd
#   clear_output(wait=True)
#   !pip install openpyxl
#   clear_output(wait=True)
#   !pip install requests_oauthlib
#   clear_output(wait=True)
#   !pip install nltk
#   clear_output(wait=True)
#   !pip install yfinance
#   clear_output(wait=True)
#   !pip install requests
#   clear_output(wait=True)
#   !pip install sec-api
#   clear_output(wait=True)
#   !pip install python-engineio
#   clear_output(wait=True)
#   !pip install python-socketio[client]
#   clear_output(wait=True)
#   !pip install fuzzywuzzy
#   clear_output(wait=True)
#   !pip install cssselect
#   clear_output(wait=True)
#   !pip install pyjarowinkler
#   clear_output(wait=True)
#   !pip install uszipcode
#   clear_output(wait=True)
#   !pip install koalas
#   clear_output(wait=True)
#   !pip install pyspark
#   clear_output(wait=True)
#   !pip install databricks
#   clear_output(wait=True)
#   print("All packages installed successfully")

# %% [markdown]
# **PreLoads: Imports**

# %%
# from urllib.request import Request

# %%
# def RunImports():
#   global Request
#   from urllib.request import Request


#   # Standard
#   import pandas as pd; global pd
#   import numpy as np; global np
#   import matplotlib.pyplot as plt; global plt
#   %matplotlib inline
#   import os; global os
#   import time; global time
#   from datetime import datetime, time; global datetime, time
#   from datetime import datetime as dt; global dt
#   import datetime; global datetime
#   import json; global json

# #   # System Framework
# #   import databricks; global databricks
# #   import databricks.koalas as ks; global ks
# #   from threading import Thread; global Thread
# #   import pyspark.pandas as ps; global ps
# #   import paramiko; global paramiko
# #   import prestodb; global prestodb
# #   import s3fs; global s3fs
# #   import boto3; global boto3
# #   import pysftp; global pysftp

# #   # NLTK
#   import nltk; global nltk
#   from nltk.corpus import stopwords; global stopwords
#   from nltk.stem import PorterStemmer; global PorterStemmer
#   nltk.download('stopwords')
  
# #   global urlopen, Request
# #   # Web Scrapping/Crawling
# #   from urllib.request import urlopen, Request; global urlopen, Request
# #   from bs4 import BeautifulSoup; global BeautifulSoup
#   import requests; global request 
#   import random; global random

# #   # Machine Learning
# #   from sklearn.feature_extraction.text import TfidfVectorizer; global TfidfVectorizer
# #   from sklearn.pipeline import Pipeline; global Pipeline
# #   from sklearn.metrics import classification_report, confusion_matrix; global classification_report, confusion_matrix
# #   from sklearn.model_selection import train_test_split; global train_test_split
# #   from sklearn.feature_selection import SelectKBest, chi2; global SelectKBest, chi2
# #   from sklearn.ensemble import RandomForestClassifier; global RandomForestClassifier
# #   from sklearn.feature_extraction.text import CountVectorizer; global CountVectorizer

# #   # Web Packages
# #   import yfinance as yf; global yf
# #   # from sec_api import *

# #   # Other
# #   from math import ceil; global ceil
# #   import io; global io
# #   import boto3; global boto3
# #   import gc; global gc
# #   import re; global re
# #   import pickle; global pickle
# #   from sqlite3 import Error; global Error
# #   import sqlite3; global sqlite3
# #   import socketio; global socketio
# #   from sodapy import Socrata; global Socrata
# #   from uszipcode import SearchEngine; global SearchEngine


# RunImports()
# print("All packages imported successfully")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# All packages imported successfully

# %%
# # Cluster Configurations
# spark.conf.set("spark.default.parallelism", 2000)
# spark.conf.set("spark.sql.shuffle.partitions", 1000)
# spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 1000000)
# spark.conf.set("spark.sql.legacy.allowCreatingManagedTableUsingNonemptyLocation", "true")
# spark.conf.set("spark.sql.crossJoin.enabled", True)


# from pyspark.context import SparkContext
# from pyspark.sql.session import SparkSession
# from pyspark.sql import HiveContext
# from pyspark import SparkConf
# from pyspark.sql import Row, Window
# from pyspark.sql.functions import udf, explode, col, split, concat,least, desc, lpad
# from pyspark.sql.functions import month,year,dayofmonth
# import pyspark.sql.functions as F
# import pyspark.sql.types as T
# from pyspark.sql.types import *
# from pyspark.sql.types import StringType
# import statistics

# from pyspark.sql.functions import udf, col
# from pyspark.sql.types import StringType

# from fuzzywuzzy import fuzz
# from pyspark.sql.functions import regexp_replace, substring_index
# # from pyspark.sql.functions import *

# from urllib.parse import urlencode, urlparse, parse_qs
# from lxml.html import fromstring
# from requests import get
# import cssselect
# from lxml import html  
# import time
# import re,urllib
# import argparse
# from pyjarowinkler import distance

# %%
import requests
import random
from tqdm import tqdm
import pandas as pd
from bs4 import BeautifulSoup
import time

import json

# %%
def Random_Agent():
  global headers_list
  user_agent_list = [
   #Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    #Firefox
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
  ]
  user_agent = random.choice(user_agent_list)
  headers_list = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': user_agent
    }
  return headers_list
Random_Agent()
